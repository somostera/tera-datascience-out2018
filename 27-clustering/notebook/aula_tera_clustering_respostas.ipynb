# %% [markdown]
# # TERA - Aula 27
# ## Clustering

# %% [markdown]
# Objetivos gerais de algoritmos de clustering:
# - Análise exploratória dos dados
# - Encontrar padrões e estruturas
# - Agrupar dados de forma a criar representações sumarizadas (sumarização de dados)

# %% [markdown]
# # Índice
#
# - [Exemplo inicial](#Exemplo-Inicial)
# - [K-Means](#K-Means)
#  - [Case K-Means Elo7](#Case-Cluster-Usuários-Elo7)
# - [Case Elo7 - Cluster Frete](#Case-Elo7---Clustering-de-Frete)
# - [Hierarchical Clustering](#Hierarchical-Clustering)
#  - [Exercício Prático](#Exercício-prático-Hierarchical-Clustering)
# - [Comparação Métodos Clustering](#Comparação-métodos-clustering:)
# - [Case Elo7 - Motivos de Compra](#Case-Elo7---Motivos-de-Compra)

# %% [markdown]
# ### Exemplo Inicial
# Análise exploratória do comportamento dos usuários do Elo7.
#
# Dataset:
# - `tempo` (float): Tempo em segundos que um usuário permanece no site.
# - `ticket` (float): Valor gasto em reais no site.

# %%
# Imports usados no curso
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss

# %%
sns.set(style="ticks")
plt.rcParams['figure.figsize'] = (12.0, 8.0)
plt.style.use('seaborn-colorblind')

# %%
# Pasta contendo os dados:
ROOT_FOLDER = os.path.realpath('..')
DATASET_FOLDER = os.path.join(ROOT_FOLDER,'datasets')

# %%
# Leitura dos dados
df_user_elo7 = pd.read_csv(os.path.join(DATASET_FOLDER, 'user_patterns_elo7_dataset.csv'), sep=';')

df_user_elo7.head(5)
# Out:
#         tempo     ticket
# 0  138.492732  63.029202
# 1  306.160891  75.160275
# 2  264.210040  74.064756
# 3  326.972183  95.059350
# 4  268.796360  47.015198

# %% [markdown]
# #### Análise Exploratória
# - Média
# - Covariância
# - Tendência (Regressão Linear)

# %%
# Valor médio
user_elo7_mean = df_user_elo7.mean().values

# Covariância
user_elo7_cov = np.cov(df_user_elo7.values[:,0], df_user_elo7.values[:,1])

# Tendência - regressão
a, b, r, p, std_err = ss.linregress(df_user_elo7.values[:,0],df_user_elo7.values[:,1])
f = lambda x: a*x + b

# %%
print('- Média: {}'.format(user_elo7_mean))
print('- Covariância: \n{}'.format(user_elo7_cov))
print('- Coeficiente de correlação da regressão: {:.2f}'.format(r))
# Out:
# - Média: [ 718.41305716   95.82494287]
# - Covariância:
# [[ 123372.18378516    6828.07629486]
#  [   6828.07629486    1709.87352627]]
# - Coeficiente de correlação da regressão: 0.47

# %% [markdown]
# Esses dados parecem interessantes, mas não são suficientes. Precisamos sempre observar os dados para tirar insights!

# %%
# Vamos plotar o gráfico
df_user_elo7.plot.scatter(x='tempo',y='ticket', alpha=0.5)
plt.xlabel('Tempo (s)')
plt.ylabel('Ticket (R$)')
plt.show()

# %%
### Função auxiliar para plotar a elipse de confiança ###
from matplotlib.patches import Ellipse

def get_confidence_ellipse(x, y, nstd=2):
    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:,order]

    cov = np.cov(x, y)
    vals, vecs = eigsorted(cov)
    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
    w, h = 2 * nstd * np.sqrt(vals)
    ell = Ellipse(xy=(np.mean(x), np.mean(y)),
                  width=w, height=h,
                  angle=theta, color='red', 
                  fill=False)
    return ell

# %%
# Vamos plotar os dados no gráfico
df_user_elo7.plot.scatter(x='tempo',y='ticket', alpha=0.5)
plt.xlabel('Tempo (s)')
plt.ylabel('Ticket (R$)')

# Média
plt.plot(user_elo7_mean[0], user_elo7_mean[1], '*r', markersize=20)

# 2 desvios padrão
ell = get_confidence_ellipse(x=df_user_elo7.values[:,0],
                             y=df_user_elo7.values[:,1])
ax = plt.gca()
ax.add_patch(ell)

# Tendência
x = np.array([min(df_user_elo7.values[:,0]),max(df_user_elo7.values[:,0])])
plt.plot(x, f(x), '--g')

plt.show()

# %% [markdown]
# Há algo estranho nessa análise?
# - A análise está matematicamente correta, mas talvez não seja completa;
# - Precisamos levar em consideração possíveis grupos diferentes de usuários dentro dos dados. Quantos grupos você vê? Talvez entre 2 e 4 clusters?
#
# Vamos utilizar o famoso algoritmo [KMeans](https://en.wikipedia.org/wiki/K-means_clustering) para encontrar esses clusters. Podemos utilizar a implementação do [sklearn](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) para isso.

# %% [markdown]
# ---
# ## K-Means

# %%
# TODO
# Importe o módulo do KMeans
from sklearn.cluster import KMeans

# Crie uma instância do K-Means pelo sklearn
# Teste diferentes números de clusters
n = 3
kmeans = KMeans(n_clusters=n)

# %% [markdown]
# Agora podemos encontrar os clusters.

# %%
kmeans.fit(df_user_elo7.values)
labels = kmeans.labels_

# %%
plt.scatter(x=df_user_elo7.values[:,0],
            y=df_user_elo7.values[:,1],
            c=labels.astype(np.float),
            cmap='rainbow',
            edgecolor='k')
plt.title('Num clusters: {}'.format(n))
plt.show()

# %% [markdown]
# Os clusters estão como esperado?
#
# Devemos **normalizar** os dados!

# %%
# Vamos normalizar os dados!
from sklearn.preprocessing import StandardScaler

# %%
# E agora plotamos o resultado
n_clusters = range(2,6)

X = df_user_elo7.values

# Dados normalizados
X_scaled = StandardScaler().fit_transform(X)

for n in n_clusters:
    estimator = KMeans(n_clusters=n, random_state=170)
    estimator.fit(X_scaled)
    labels = estimator.labels_
    plt.scatter(x=X_scaled[:,0],
                y=X_scaled[:,1],
                c=labels.astype(np.float),
                cmap='rainbow',
                edgecolor='k')
    plt.title('Num clusters: {}'.format(n))
    plt.show()

# %% [markdown]
# Ok... podemos ver que podemos encontrar algumas opções de número de clusters, mas qual é o valor ideal?

# %% [markdown]
# #### Escolha do número de clusters
#
# Nós temos diversos métodos para escolher o número ideal de clusters. Alguns deles estão resumidos neste [artigo](https://en.wikipedia.org/wiki/Determining_the_number_of_clusters_in_a_data_set#The_Elbow_Method). O método mais utilizado, entretanto, é o método do "cotovelo" (*elbow method*).
#
# Mas, antes de falarmos do método do cotovelo, nós precisamos definir o que é um bom cluster. É claro que isso depende de cada caso, mas as seguintes características são desejadas para a maioria dos clusters:
# - Dados não muito dispersos -> Inércia
# - Dados dentro dos clusters possuem perfil semelhante
# - Quantidade aproximadamente uniforme de dados em cada cluster (controverso)
#
# #### Inércia
#
# A inércia de um cluster é definida como a soma das distâncias quadráticas de cada ponto de um cluster ao seu respectivo centroide, somada através de todos os clusters. Quanto maior é a inércia, maior será a dispersão dos clusters. Portanto, desejamos escolher um número de clusters que nos possibilite ter uma inércia baixa. Simples, mas temos um problema... O mínimo valor de inércia que podemos obter é quando cada ponto do nosso dataset pertence ao seu próprio cluster. Portanto, precisamos escolher um balanço entre baixa inércia e baixo número de clusters.
#
# Para isso, utilizamos o gráfico de cotovelo. O eixo horizontal do gráfico representa o número de clusters utilizados e o eixo vertical representa a inércia total dos clusters. O número de clusters ideal é definido como o ponto onde o gráfico se aproxima a uma horizontal (como o ponto de encontro do braço e antebraço).

# %%
# Range de valores de clusters que vamos testar
k = range(1,8,1)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X_scaled)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Qual a sua opinião? Quantos clusters devemos utilizar? (Eu escolheria 3!)

# %%
estimator = KMeans(n_clusters=3)
estimator.fit(X_scaled)
labels = estimator.labels_

plt.scatter(x=X_scaled[:,0],
            y=X_scaled[:,1],
            c=labels.astype(np.float),
            cmap='rainbow',
            edgecolor='k')
plt.title('Num clusters: {}'.format(n))
plt.show()

# %% [markdown]
# ---
# ## Case Elo7 - Clustering de Frete
#
# Um dos problemas mais complicados do Elo7 é sua dependência dos correios. Nós sofremos muito com a falta de alternativas para dar aos nossos clientes (compradores e vendedores), já que o serviço dos correios além de caro, é também instável.
#
# Para tentar resolver esse problema, o time de Data Science do Elo7 foi chamado para tentar encontrar alguma alternativa. Após algumas conversas, nós levantamos a possibilidade de utilizarmos serviços de entrega independentes dos correios. Mas, o problema é que esses serviços necessitam de um volume grande de encomendas por ponto de coleta, o que não é o caso para a maioria dos vendedores cadastrados no Elo7.
#
# Uma possível solução seria encontrar pontos de coleta que pudessem agregar pedidos de vários vendedores e enviar de uma vez só com um desses serviços alternativos. Mas, como obtemos a localização desses pontos de coleta? Podemos aplicar um algoritmo de clustering nas rotas de frete mais frequentes!
#
# Vamos tentar analisar os dados e verificar o que conseguimos obter. O dataset a seguir contém pares de endereços de origem e destino de entregas realizadas apenas na cidade de São Paulo em um curto intervalo de tempo.

# %%
df_route = pd.read_csv(os.path.join(DATASET_FOLDER, 'route_clustering_elo7_dataset.csv'), sep=';')

df_route.head()
# Out:
#   cep_origem  latitude_origem  longitude_origem cep_destino  latitude_destino  \
# 0  02854-000       -23.458472        -46.697457   05661-000        -23.608533
# 1  04563-000       -23.610779        -46.685776   05410-000        -23.557603
# 2  08265-000       -23.572392        -46.452325   02976-000        -23.481036
# 3  04195-000       -23.656972        -46.613229   03426-000        -23.552227
# 4  02235-000       -23.479388        -46.581890   05036-000        -23.516369
#
#    longitude_destino
# 0         -46.729718
# 1         -46.676987
# 2         -46.715047
# 3         -46.537025
# 4         -46.690578

# %% [markdown]
# Para facilitar os cálculos de distância, as latitudes e longitudes dos locais já foram realizados.

# %% [markdown]
# Vamos agora formar nosso vetor de features contendo as posições geográficas das nossas rotas.
#
# *Dica: Será que é necessário normalizar as features?

# %%
# TODO
X = df_route[['latitude_origem','longitude_origem','latitude_destino','longitude_destino']].values
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# Quantos clusters vamos utilizar? (Obs: Podemos aplicar o método do cotovelo para descobrir.)

# %%
# TODO
# Range de valores de clusters que vamos testar
k = range(1,10,1)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X_scaled)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Agora podemos iniciar o algoritmo de clustering.

# %%
# TODO
kmeans = KMeans(n_clusters=5)

# %%
# TODO
labels = kmeans.fit_predict(X_scaled)

# %% [markdown]
# A análise da quantidade de ítens em cada cluster é sempre uma boa prática. Clusters desbalanceados são um sinal de que os dados não foram bem separados.

# %%
label, count = np.unique(labels, return_counts=True)
for l, c in zip(label,count):
    print('Cluster {}: {}'.format(l,c))
# Out:
# Cluster 0: 819
# Cluster 1: 844
# Cluster 2: 891
# Cluster 3: 719
# Cluster 4: 863

# %% [markdown]
# Vamos ver os gráficos para analisar qualitativamente os resultados.

# %%
labels = kmeans.labels_

ax1 = plt.subplot(1,2,1)
ax1.set_title('Origem')
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax1.set_xlim((-23.4,-23.9))

ax2 = plt.subplot(1,2,2)
ax2.set_title('Destino')
plt.scatter(x=X[:,2],
            y=X[:,3],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax2.set_xlim((-23.4,-23.9))

plt.show()

# %% [markdown]
# O que achou? É possível perceber clusters bem definidos? Será que podemos utilizar esses clusters para resolver nossos problemas de frete?

# %% [markdown]
# ---
# ### Exemplo Prático - Kaggle NYC Taxi Trip Duration
#
# Dados:
# - id - a unique identifier for each trip
# - vendor_id - a code indicating the provider associated with the trip record
# - pickup_datetime - date and time when the meter was engaged
# - dropoff_datetime - date and time when the meter was disengaged
# - passenger_count - the number of passengers in the vehicle (driver entered value)
# - pickup_longitude - the longitude where the meter was engaged
# - pickup_latitude - the latitude where the meter was engaged
# - dropoff_longitude - the longitude where the meter was disengaged
# - dropoff_latitude - the latitude where the meter was disengaged
# - store_and_fwd_flag - This flag indicates whether the trip record was held in vehicle memory before sending to the vendor because the vehicle did not have a connection to the server - Y=store and forward; N=not a store and forward trip
# - trip_duration - duration of the trip in seconds
#
# ![iris](https://cdn.civitatis.com/estados-unidos/nueva-york/galeria/thumbs/taxi-nueva-york.jpg)
#
# *Solução retirada do github de [juifa-tsai](https://github.com/juifa-tsai/NYC_Taxi_Trip_Duration).

# %% [markdown]
# Vamos realizar uma análise dos dados.

# %%
df_taxi = pd.read_csv(os.path.join(DATASET_FOLDER,'nyc_trip_duration_dataset.csv'))

# %%
df_taxi.head(5)
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id3070488          1  2016-05-10 09:36:01  2016-05-10 09:51:36
# 1  id3797315          1  2016-05-30 00:29:32  2016-05-30 00:34:08
# 2  id2982351          1  2016-02-13 22:03:12  2016-02-13 22:13:08
# 3  id0576937          2  2016-05-15 00:19:30  2016-05-15 00:39:14
# 4  id3672156          1  2016-01-20 08:59:47  2016-01-20 09:18:15
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.960396        40.773849         -73.982414
# 1                1        -73.999039        40.734386         -74.007629
# 2                2        -74.012695        40.701694         -74.011086
# 3                1        -73.950188        40.783958         -73.867882
# 4                1        -74.001541        40.746754         -73.978409
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.775364                  N            935
# 1         40.741051                  N            276
# 2         40.729237                  N            596
# 3         40.845356                  N           1184
# 4         40.750282                  N           1108

# %% [markdown]
# Podemos utilizar diversas abordagens para analisar os dados. Vamos tentar verificar os dados de localização dos passageiros.

# %%
df_map = df_taxi[['pickup_longitude','pickup_latitude', 'dropoff_longitude','dropoff_latitude']]
df_pick = df_map[['pickup_longitude','pickup_latitude']]
df_drop = df_map[['dropoff_longitude','dropoff_latitude']]

# %% [markdown]
# Vamos visualizar os dados.

# %%
def plot_map(df, zoom=0.9):
    cutmap = zoom/100

    x = df['pickup_longitude']
    y = df['pickup_latitude']
    x_max, x_min = x.quantile(1-cutmap), x.quantile(cutmap)
    y_max, y_min = y.quantile(1-cutmap), y.quantile(cutmap)
    
    x_plot = x[(x>x_min) & (x<x_max) & (y<y_max) & (y>y_min)]
    y_plot = y[(x>x_min) & (x<x_max) & (y<y_max) & (y>y_min)]
    plt.scatter(x=x_plot, y=y_plot, s=5, alpha=0.3)
    plt.tick_params(labelsize=18)
    plt.title('Pickup', fontsize=18 )
    plt.xlabel('Longitude', fontsize=18)
    plt.ylabel('Latitude',  fontsize=18)
    plt.show()

plot_map(df_taxi)

# %% [markdown]
# A distribuição dos dados é bem interessante. Podemos verificar que existe uma concentração grande de pontos dentro da ilha de Manhattan, o que é esperado.

# %% [markdown]
# Como segundo passo da análise dos dados, nós podemos tentar enriquecê-los utilizando técnicas de feature engineering e clustering. Vamos explorar o segundo em seguida.

# %% [markdown]
# O racional de utilizar clustering para análise exploratória e feature engineering é o fato de encontrar estruturas implícitas nos dados. Por exemplo, se tentássemos observar cada passageiro individualmente, talvez teríamos dificuldade em encontrar um padrão nos dados. Mas, é intuitivo pensar que passageiros semelhantes (mesma localização, horário etc) possam ser agrupados e tratados como um só. Assim, podemos tratar os dados por grupos controlados de passageiros, ao invés de cada indivíduo.

# %% [markdown]
# Vamos tentar encontrar clusters nos dados de início da corrida de taxi.

# %%
kmeans = KMeans(n_clusters=20)

# %%
X_kmeans = kmeans.fit_predict(df_pick)
df_pick['zone']  = X_kmeans
# Out:
# /home/rballet/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def draw_map_zone( df, x_name, y_name, z_name, name, zoom=0.9, cluster=None ):

    x = df[x_name]
    y = df[y_name]
    z = df[z_name]

    cutmap = zoom/100
    x_max, x_min = x.quantile(1-cutmap), x.quantile(cutmap)
    y_max, y_min = y.quantile(1-cutmap), y.quantile(cutmap)
    
    zones = np.unique(z[(x>x_min) & (x<x_max) & (y<y_max) & (y>y_min)])

    #cmap = plt.get_cmap('spectral') 
    cmap = plt.get_cmap('winter') 
    colors = [cmap(i) for i in np.linspace(0, 1, len(zones))]

    for i, zone in enumerate(zones):       
        plt.scatter( x=x[ (z==zone) & (x>x_min) & (x<x_max) & (y<y_max) & (y>y_min) ], 
                     y=y[ (z==zone) & (x>x_min) & (x<x_max) & (y<y_max) & (y>y_min) ], 
                     s=5, alpha=0.3, c=colors[i])
        if cluster:
            plt.text( cluster.cluster_centers_[zone,0], cluster.cluster_centers_[zone,1], str(zone), fontsize = 12, color='r')

    plt.tick_params(labelsize=18)
    plt.title(name, fontsize=18 )
    plt.xlabel('Longitude', fontsize=18)
    plt.ylabel('Latitude',  fontsize=18)


plt.figure(figsize=(17,15))
draw_map_zone(df_pick, 'pickup_longitude', 'pickup_latitude', 'zone', 'Pickup', cluster=kmeans)
plt.show()

# %% [markdown]
# Não por acaso, os clusters encontrados se assemelham aos bairros de Nova Iorque. Esses clusters agora podem ser utilizados de diversas formas:
# - Podemos explorar a distribuição das outras features dentro de cada um dos clusters. Assim poderemos ver o quanto cada região se diferença das outras.
# - Podemos também utilizar agora as labels obtidas pelo algoritmo de clustering como entrada de outros algoritmos de machine learning. Essa técnica é muito utilizada para melhorar a precisão dos algoritmos de regressão e classificação.

# %% [markdown]
# Vamos tentar utilizar clustering na solução encontrada na [aula 15](https://github.com/somostera/tera-dsc-abr2018/blob/master/15-ml-with-decision-trees/notebooks/Gabarito%20Aula%2015%20-%20AM%20com%20%C3%81rvores%20de%20Decis%C3%A3o.ipynb) para verificar se conseguimos aumentar a precisão do regressor.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=5,random_state=0)

df_taxi_cluster = df_taxi.copy()

kmeans = KMeans(n_clusters=100)
X_kmeans = kmeans.fit_predict(df_map)
df_taxi_cluster['zone'] = X_kmeans

x = df_taxi.drop(['trip_duration', 'id', 'pickup_datetime', 'dropoff_datetime', 'store_and_fwd_flag'], axis=1)
y = df_taxi['trip_duration']

x_cluster = df_taxi_cluster.drop(['trip_duration', 'id', 'pickup_datetime', 'dropoff_datetime', 'store_and_fwd_flag'], axis=1)

reg = DecisionTreeRegressor()

# %%
def make_cv_prediction(x,y,train_index,test_index,reg):
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    return y_pred, y_test

def rmsle(y_test, y_pred):
    return np.sqrt(mean_squared_log_error(y_test,y_pred))

rmsle_cv_default = []
rmsle_cv_cluster = []
for train_index, test_index in kfold.split(x,y):
    y_pred, y_test = make_cv_prediction(x,y,train_index,test_index,reg)
    rmsle_cv_default.append(rmsle(y_test, y_pred))
    
    y_pred_cluster, y_test = make_cv_prediction(x_cluster,y,train_index,test_index,reg)
    rmsle_cv_cluster.append(rmsle(y_test, y_pred_cluster))

# %%
print('Default: {:.4f}'.format(np.mean(rmsle_cv_default)))
print('Cluster: {:.4f}'.format(np.mean(rmsle_cv_cluster)))
# Out:
# Default: 0.6841
# Cluster: 0.6724

# %% [markdown]
# Pode-se notar um ligeiro aumento de precisão do estimador ao utilizar o cluster.

# %% [markdown]
# ---
# ## Hierarchical Clustering
#
# Vamos agora aprender sobre outro método de clustering: [**Hierarchical Clustering**](https://en.wikipedia.org/wiki/Hierarchical_clustering). Como o nome mesmo diz, ele utiliza o conceito de *hierarquia* para construir os clusters. Existem duas principais variações do algoritmo: aglomerativo e por divisão. O primeiro é mais usado na prática. O passo a passo do algoritmo é apresentado abaixo:
#
# - Primeiro colocamos todos as observações em clusters próprios (individuais);
# - Depois, iterativamente procuramos os clusters mais próximos\* e agrupamos eles em um novo cluster;
# - Repetimos o passo anterior até formarmos um único cluster com todas as observações.
#
# \*Obs: A definição de distância (ou similaridade) entre clusters depende do tipo de métrica de distância (Euclidiana, Manhattan, cosseno etc) e ligação (Ward, simples, completa etc).
#
# Como podemos ver no algoritmo, o objetivo é a criação de um grande cluster que agrupe todos os dados. Nós podemos visualizar esse histórico de agrupamentos a partir de um [dendrograma](https://en.wikipedia.org/wiki/Dendrogram). A então criação de clusters mais granulares depende da região de similaridade que se deseja realizar o corte.

# %% [markdown]
# Vamos aplicar o método de Hierarchical Clustering no dataset de usuários do Elo7.

# %%
df_user_elo7 = pd.read_csv(os.path.join(DATASET_FOLDER, 'user_patterns_elo7_dataset.csv'), sep=';')

X = df_user_elo7.values

# Dados normalizados
X_scaled = StandardScaler().fit_transform(X)

# %%
# Importe os métodos linkage (Hierarchical Clustering) e dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

# %% [markdown]
# O scikit-learn possui um método próprio para o algoritmo de [Hierarchical Clustering](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#sklearn.cluster.AgglomerativeClustering). Entretanto, ele não nos permite visualizar facilmente o dendrograma final. Por isso, vamos utilizar a versão do scipy.

# %%
# Vamos escolher a métrica de distância:
distance = 'euclidean'
# Agora o tipo de ligação
linkage_type = 'ward'

# Vamos aplicar o método linkage
Y = linkage(X_scaled, method=linkage_type, metric=distance)

# %% [markdown]
# Teste outros tipos de ligação e distâncias! Para verificar quais distâncias estão disponíveis, acesse esse [link](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.pdist.html#scipy.spatial.distance.pdist).

# %%
Y.shape
# Out:
# (299, 4)

# %%
# Vamos visualizar o dendrograma
plt.figure(figsize=(16,10))
dendrogram(Y,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.show()

# %% [markdown]
# O que achou? Teste outros valores de distância e tipo de ligação para verificar as diferenças nos resultados!
#
# O dendrograma nos permite verificar qual é o número de clusters que vamos escolher ao final. Além disso, podemos verificar se a distância e o tipo de ligação foram bem escolhidos.
#
# O que precisamos fazer agora é escolher o número de clusters. Podemos utilizar o mesmo método do cotovelo para esse objetivo, mas, na prática, podemos apenas visualizar qual é a região que possui maior distância entre aglutinações. Outros trabalhos ainda utilizam um coeficiente de [Correlação Cofenética](https://en.wikipedia.org/wiki/Cophenetic_correlation) para encontrar uma boa posição de corte no dendrograma.

# %% [markdown]
# Para essa tarefa nós podemos usar o método [`fcluster`](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.cluster.hierarchy.fcluster.html) do scipy. Ele nos permite realizar um corte na árvore de clustering gerada pelo Hierarchical Clustering.

# %%
from scipy.cluster.hierarchy import fcluster

# %%
# Vamos gerar os rótulos para os clustes
num_clusters = 3
labels = fcluster(Y, num_clusters ,criterion='maxclust')

# %%
plt.scatter(x=X_scaled[:,0],
            y=X_scaled[:,1],
            c=labels.astype(np.float),
            cmap='rainbow',
            edgecolor='k')
plt.title('Num clusters: {}'.format(num_clusters))
plt.show()

# %% [markdown]
# ---
# ## Case Elo7 - Clustering de Frete

# %% [markdown]
# Vamos tentar aplicar o mesmo algoritmo para o problema de cluster de frete.

# %%
df_route = pd.read_csv(os.path.join(DATASET_FOLDER, 'route_clustering_elo7_dataset.csv'), sep=';')

df_route.head()
# Out:
#   cep_origem  latitude_origem  longitude_origem cep_destino  latitude_destino  \
# 0  02854-000       -23.458472        -46.697457   05661-000        -23.608533
# 1  04563-000       -23.610779        -46.685776   05410-000        -23.557603
# 2  08265-000       -23.572392        -46.452325   02976-000        -23.481036
# 3  04195-000       -23.656972        -46.613229   03426-000        -23.552227
# 4  02235-000       -23.479388        -46.581890   05036-000        -23.516369
#
#    longitude_destino
# 0         -46.729718
# 1         -46.676987
# 2         -46.715047
# 3         -46.537025
# 4         -46.690578

# %%
X = df_route[['latitude_origem','longitude_origem','latitude_destino','longitude_destino']].values
X_scaled = StandardScaler().fit_transform(X)

# %%
# Vamos escolher a métrica de distância:
distance = 'euclidean'
# Agora o tipo de ligação
linkage_type = 'ward'

# Vamos aplicar o método linkage
Y = linkage(X_scaled, method=linkage_type, metric=distance)

# %%
# Vamos visualizar o dendrograma
plt.figure(figsize=(16,10))
dendrogram(Y,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.show()

# %%
# Vamos gerar os rótulos para os clustes
num_clusters = 4
labels = fcluster(Y, num_clusters ,criterion='maxclust')

# %%
ax1 = plt.subplot(1,2,1)
ax1.set_title('Origem')
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax1.set_xlim((-23.4,-23.9))

ax2 = plt.subplot(1,2,2)
ax2.set_title('Destino')
plt.scatter(x=X[:,2],
            y=X[:,3],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax2.set_xlim((-23.4,-23.9))

plt.show()

# %% [markdown]
# ---
# # Case Elo7 - Motivos de Compra
#
# Os compradores do Elo7 são incentivados a indicar o motivo da compra de determinado produto no seu marketplace. Esses motivos nos ajudam a entender melhor o **momento** de compra do usuário. O dataset apresentado a seguir contém um subset desses motivos de compra.

# %%
df_reason = pd.read_csv(os.path.join(DATASET_FOLDER, 'purchase_reason_elo7_dataset.csv'), sep=';')

df_reason.head(10)
# Out:
#                               product_title  \
# 0          apliques recortados fundo do mar
# 1            mini raposa vermelha amigurumi
# 2                 o pequeno principe i bata
# 3        quadro maternidade menino elefante
# 4            livro de votos casamento o par
# 5       caixa 40 charuto de chocolate belga
# 6            arquivo de corte vamos brindar
# 7    prateleira com varao mdf reta 96x20x14
# 8                     colherzinha bailarina
# 9  caixa cone arvore jardim dos passarinhos
#
#                                reason
# 0        festa de 2 anos do meu filho
# 1                   presente para mim
# 2                         aniversario
# 3              nascimento do meu bebe
# 4                           casamento
# 5            lembranca de maternidade
# 6                       mimo para mim
# 7  decoracao do quarto da minha filha
# 8                         aniversario
# 9                               festa

# %% [markdown]
# Existem muitos tipos possíveis de motivos de compra, mas será que nós podemos encontrar algum padrão neles? Me parece um problema clássico de **clustering**.

# %% [markdown]
# Vamos utilizar o Tf-Idf para criar o embedding dos motivos de compra e o K-Means para encontrar clusters.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_df=0.9, max_features=5000, sublinear_tf=True, use_idf=True)

# %% [markdown]
# Cria a matriz de embeddings.

# %%
# TODO
X = tfidf.fit_transform(df_reason['reason'].values)

# %% [markdown]
# Como escolher o número de clusters? Vamos utilizar o gráfico de inércias. (Obs: outra possibilidade é avaliar o ["silhouette score"](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html#sphx-glr-auto-examples-cluster-plot-kmeans-silhouette-analysis-py)).

# %%
# TODO
# Range de valores de clusters que vamos testar
k = range(10,200,20)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Inicializa o K-Means com a quantidade de clusters que escolhemos a partir do gráfico.

# %%
# TODO
kmeans = KMeans(n_clusters=50)

# %% [markdown]
# Treina o modelo K-Means.

# %%
# TODO
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=50, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Encontra os clusters para cada motivo de compra.

# %%
# TODO
labels = kmeans.predict(X)

# %% [markdown]
# Vamos agora visualizar os clusters criados.

# %%
# Crie um novo dataframe com os labels dos clusters
df = pd.DataFrame({'reason': df_reason['reason'], 'labels': labels})

df.head()
# Out:
#    labels                        reason
# 0      44  festa de 2 anos do meu filho
# 1      39             presente para mim
# 2       1                   aniversario
# 3      41        nascimento do meu bebe
# 4      15                     casamento

# %% [markdown]
# Vamos verificar a distribuição de motivos em cada cluster. Quanto mais desbalanceado, pior.

# %%
df.groupby('labels').size()
# Out:
# labels
# 0       437
# 1      8874
# 2      6412
# 3      1950
# 4       433
# 5       740
# 6      1351
# 7      4795
# 8      6290
# 9      2041
# 10     2756
# 11     2087
# 12    12285
# 13     1151
# 14     1281
# 15     6260
# 16     1681
# 17     1455
# 18      936
# 19     1448
# 20     1372
# 21      379
# 22     1293
# 23      565
# 24     1299
# 25     1681
# 26     2073
# 27     1047
# 28      542
# 29     1025
# 30      213
# 31     1390
# 32     1775
# 33     1271
# 34     1738
# 35     1580
# 36      455
# 37      912
# 38      614
# 39     2349
# 40     1053
# 41      922
# 42     1324
# 43     1526
# 44     1081
# 45     1004
# 46     1272
# 47     1957
# 48     1320
# 49      305
# dtype: int64

# %% [markdown]
# Podemos visualizar alguns exemplos de clusters gerados pelo K-Means.

# %%
for idx in range(50):
    idx_labels = df[df['labels']==idx]['reason'].unique()
    print('- Cluster {}:'.format(idx + 1))
    for i in np.random.choice(idx_labels, min(len(idx_labels), 10), replace=False):
        print(' '*5, i)
    print()
# Out:
# - Cluster 1:
#       fazer artesanato
#       faco artesanato
#       artesanato
#       material para artesanato
#       para meu artesanato
#       para fazer artesanato
#       uso em artesanato
#       para artesanato
#       trabalho com artesanato
#       confeccao de artesanato
#
# - Cluster 2:
#       para aniversario
#       aniversario
#
# - Cluster 3:
#       presente
#       para presente
#       meu presente
#       presente para aniversario
#       presente aniversario
#
# - Cluster 4:
#       para meu casamento
#       meu casamento
#       convites do meu casamento
#       lembrancas para meu casamento
#       comprei para o meu casamento
#       para o meu casamento
#       convites para o meu casamento
#       lembrancas do meu casamento
#       pro meu casamento
#       lembrancinha para meu casamento
#
# - Cluster 5:
#       para minha bebe
#       para o quartinho da minha bebe
#       festa da minha bebe
#       presente para a minha bebe
#       minha bebe
#       quartinho da minha bebe
#       mesversario da minha bebe
#       aniversario da minha bebe
#       minha
#       pra minha bebe
#
# - Cluster 6:
#       necessidade pessoal
#       compra pessoal
#       pessoal
#       mimo pessoal
#       presente pessoal
#       arquivo pessoal
#       organizacao pessoal
#
# - Cluster 7:
#       mim mesma
#       foi para mim mesma
#       compra para mim mesma
#       presente p mim mesma
#       presente para mim mesma
#       mimos para mim mesma
#       para mim mesma
#       p mim mesma
#       comprei para mim mesma
#
# - Cluster 8:
#       decoracao de aniversario da minha filha
#       convite do aniversario da minha filha
#       presente de aniversario da minha filha
#       aniversario da minha afilhada
#       convite aniversario da minha filha
#       lembrancinha da minha filha
#       festinha da minha filha
#       lembrancinhas para aniversario da minha filha
#       para o quartinho da minha filha
#       lembrancinhas aniversario da minha filha
#
# - Cluster 9:
#       convite de aniversario do meu filho
#       lembrancinha para o aniversario do meu filho
#       presente do meu filho
#       lembrancinhas para o aniversario do meu filho
#       comprei para o aniversario do meu filho
#       casamento do meu filho
#       aniversario do meu filho de 2 anos
#       aniversario de 7 anos do meu filho
#       aniversario de 5 anos do meu filho
#       festinha do meu filho
#
# - Cluster 10:
#       uma ocasiao muito especial
#       uma ocasiao especial aniversario da minha filha
#       ocasiao especial aniversario
#       presente especial
#       ocasiao muito especial
#       ocasiao especial aniversario da minha filha
#       nenhuma ocasiao especial
#       ocasiao especial casamento
#       uma ocasiao especial
#       ocasiao especial meu casamento
#
# - Cluster 11:
#       para meu cha de cozinha
#       cha de fralda
#       cha de bb
#       lembranca do cha de bebe
#       cha de revelacao
#       cha de bebe do meu sobrinho
#       cha revelacao
#       cha de bebe do meu afilhado
#       meu cha revelacao
#       meu cha bar
#
# - Cluster 12:
#       material para trabalho
#       trabalho pessoal
#       para meu trabalho
#       trabalho escolar
#       uso trabalho
#       para o trabalho
#       uso para trabalho
#       meu trabalho
#       para trabalho
#       trabalho de escola
#
# - Cluster 13:
#       para meu bebe que vai nascer
#       comemoracao
#       para min
#       convites de aniversario
#       evento
#       material escolar
#       presente para filha de uma amiga
#       festas
#       uso em meus trabalhos
#       debutante
#
# - Cluster 14:
#       lembrancinha aniversario infantil
#       lembrancinha festa
#       lembrancinha aniversario
#       lembrancinha 1 aninho
#       lembrancinha aniversario filha
#       lembrancinha festa infantil
#       lembrancinha casamento
#       lembrancinha aniversario meu filho
#       aniversario lembrancinha
#       lembrancinha aniversario filho
#
# - Cluster 15:
#       para meu uso proprio
#       para meu proprio uso
#       compra para uso proprio
#       proprio
#       uso proprio
#       uso proprio e presente
#       comprei para uso proprio
#       presente proprio
#       para uso proprio
#       presente e uso proprio
#
# - Cluster 16:
#       para casamento
#       para o casamento
#       casamento
#       aniversario de casamento
#       presente casamento
#       casamento filha
#       presente para casamento
#       presente de casamento
#
# - Cluster 17:
#       enfeitar a casa
#       mimo pra casa
#       para casa nova
#       para minha nova casa
#       decoracao de minha casa
#       decorar a casa
#       decorar minha casa
#       decoracao minha casa
#       casa
#       organizacao da casa
#
# - Cluster 18:
#       decoracao de mesa
#       decoracao de aniversario
#       decoracao infantil
#       decoracao para casamento
#       para decoracao
#       decoracao de casamento
#       decoracao da minha cozinha
#       aniversario decoracao
#       decoracao da sala
#       para decoracao de aniversario
#
# - Cluster 19:
#       lembranca da maternidade
#       saida maternidade
#       lembranca de maternidade
#       quadro maternidade
#       porta da maternidade
#       kit maternidade
#       enfeite maternidade
#       enfeite porta maternidade
#       porta maternidade
#       lembrancas maternidade
#
# - Cluster 20:
#       presente para meu filho
#       pro meu filho
#       para o filho
#       meu filho
#       filho
#       presente p meu filho
#       para filho
#       presente meu filho
#       presente pro meu filho
#       para meu filho
#
# - Cluster 21:
#       niver sobrinha
#       festa de niver
#       niver filhote
#       festa niver
#       niver do filho
#       niver da minha bb
#       niver do neto
#       niver neto
#       niver 2 anos
#       niver do meu bebe
#
# - Cluster 22:
#       decoracao festa
#       para decoracao de festa
#       decoracao festa de aniversario
#       decoracao festa infantil
#       decoracao para festa
#       decoracao para festa infantil
#       decoracao para festa de aniversario
#       decoracao da festa
#       decoracao de aniversario infantil
#       decoracao festa aniversario
#
# - Cluster 23:
#       convite para padrinhos de batizado
#       convite do meu aniversario
#       caixa convite para padrinhos
#       convite de casamento
#       convite dos padrinhos
#       convite para meus padrinhos de casamento
#       convite de padrinhos de casamento
#       convite de batismo
#       convite para minha filha
#       convite padrinhos batismo
#
# - Cluster 24:
#       festa filhos
#       quarto dos filhos
#       presente para os meus filhos
#       lembrancinha de aniversario dos meus filhos
#       presente para meus filhos
#       festa de aniversario dos meus filhos
#       aniversario de meus filhos
#       aniversario dos meus netos
#       aniversario dos filhos
#       presente para filhos
#
# - Cluster 25:
#       aniversario de um ano da minha filha
#       aniversario de 01 ano do meu filho
#       aniversario de 1 ano do meu bebe
#       lembrancinha aniversario de 1 ano
#       aniversario de 1 ano de minha filha
#       lembranca 1 ano
#       lembrancinha de 1 ano
#       festa de aniversario de 1 ano
#       aniversario de 1 ano meu filho
#       festa 1 ano
#
# - Cluster 26:
#       decoracao do quarto da minha bebe
#       decoracao quarto infantil
#       quarto do meu filho
#       decoracao do quarto das minhas filhas
#       enfeite quarto bebe
#       decoracao para o quarto da minha filha
#       decoracao do quarto
#       decoracao quarto da minha bebe
#       quarto bebe
#       quarto da minha bebe
#
# - Cluster 27:
#       uma festa
#       para uma festa
#       festa aniversario
#       para minha festa
#       festa 1 aninho
#       festa
#       para festa
#       festa infantil
#       festa sobrinho
#       festa filha
#
# - Cluster 28:
#       festa do meu principe
#       aniversario de 1 ano do meu principe
#       aniversario do principe
#       aniversario meu principe
#       presente para meu pequeno principe
#       niver meu principe
#       presente pro meu principe
#       presente para meu principe
#       1 aninho do meu principe
#       cha de fraldas do meu principe
#
# - Cluster 29:
#       dia dos namorados
#       presente dia dos namorados
#       presente dia dos pais
#       presente para dia dos professores
#       presente dia do professor
#       presente para o dia dos namorados
#       dia das criancas
#       lembranca dia dos professores
#       presente dia das criancas
#       presente dia das maes
#
# - Cluster 30:
#       15 anos da minha princesa
#       aniversario 30 anos
#       lembranca 15 anos
#       aniversario de 3 anos
#       aniversario da minha filha 2 anos
#       15 anos da minha filha
#       lembranca de 15 anos
#       aniversario de 5 anos
#       meus 15 anos
#       aniversario de 2 anos
#
# - Cluster 31:
#       presentes para padrinhos
#       presentes para mim
#       presentes para amigas
#       presentes de natal
#       presentes
#
# - Cluster 32:
#       batizado do meu bebe
#       batizado da minha filha
#       batizado do meu afilhado
#       batizado do meu sobrinho
#       batizado da minha pequena
#       lembranca de batizado
#       para o batizado da minha filha
#       decoracao batizado
#       batizado do meu neto
#       lembrancinha de batizado
#
# - Cluster 33:
#       mimo para minha filha
#       presente para a filha
#       presente minha filha
#       presente de aniversario para minha filha
#       para minha filha
#       para filha
#       comprei para minha filha
#       presente filha
#       para mim e minha filha
#       presente para filha
#
# - Cluster 34:
#       mimo p mim
#       mimo para eu mesma
#       mimo p mim mesma
#       mimo para filha
#       mimo para mim mesma
#       mimo para mim
#       um mimo para mim mesma
#       mimo para meu casamento
#       mimo
#       mimo para minha cozinha
#
# - Cluster 35:
#       presente pra minha filha
#       pra minha filha
#       presente pra mim
#       presente pra minha sobrinha
#       presente pra mim mesma
#       presente pra afilhada
#       pra mim msm
#       comprei pra mim
#       mimo pra mim mesmo
#       presente pra minha princesinha
#
# - Cluster 36:
#       aniver da minha princesa
#       lembranca de aniversario da minha princesa
#       para minha princesa
#       presente pra minha princesa
#       convite de aniversario da minha princesa
#       para aniversario da minha princesa
#       convite da minha princesa
#       decoracao quarto da minha princesa
#       princesa
#       aniversario de minha princesa
#
# - Cluster 37:
#       foi um presente
#       presente para um casal de amigos
#       um mimo para mim
#       um mimo pra mim
#       um presente para mim mesma
#       presente para um bebe
#       aniversario de um aninho
#       era um presente
#       um presente para minha filha
#       um aniversario
#
# - Cluster 38:
#       lembrancinhas
#       lembrancinhas nascimento
#       lembrancinhas batizado
#       lembrancinhas para meu casamento
#       confeccao de lembrancinhas
#       lembrancinhas para festa de aniversario
#       lembrancinhas do meu casamento
#       lembrancinhas de aniversario
#       fazer lembrancinhas
#       lembrancinhas para o meu casamento
#
# - Cluster 39:
#       decoracao natal
#       lembrancas de natal
#       natal
#       lembrancinha de natal
#       presente para o natal
#       enfeite de natal
#       presente de natal
#       festa de natal
#       presente natal
#       lembranca de natal
#
# - Cluster 40:
#       comprei para mim mesmo
#       compra para mim
#       para mim e para presente
#       p mim
#       para mim mesmo
#       para
#       presente p mim
#       mim mesmo
#       p mim mesmo
#       presente para mim
#
# - Cluster 41:
#       para o quartinho do meu bebe
#       mesversario do meu bebe
#       aniversario meu bebe
#       presente pro meu bebe
#       festa do meu bebe
#       presente para o bebe
#       para o meu bebe
#       aniversario do meu bebe
#       presente bebe
#       pro meu bebe
#
# - Cluster 42:
#       lembranca de nascimento
#       lembrancinha de nascimento da minha filha
#       nascimento da minha filha
#       lembrancinha nascimento
#       nascimento do filho
#       nascimento de minha filha
#       nascimento do meu segundo filho
#       nascimento filho
#       nascimento da filha
#       nascimento minha filha
#
# - Cluster 43:
#       para o aniversario de minha filha
#       casamento de minha filha
#       minha filha
#       aniversario minha filha
#       lembrancinha aniversario minha filha
#       p minha filha
#       filha
#       aniversario de filha
#       aniversario de minha filha
#       aniversario filha
#
# - Cluster 44:
#       lembranca para casamento
#       lembranca de formatura
#       lembranca para madrinhas
#       aniversario lembranca
#       lembranca de casamento
#       lembranca dos padrinhos
#       lembranca padrinhos
#       lembranca para festa
#       lembranca de aniversario infantil
#       lembranca madrinhas
#
# - Cluster 45:
#       para festa do meu filho
#       festa do filho
#       festa aniversario meu filho
#       festa do meu neto
#       lembrancinha para a festa do meu filho
#       para a festa de aniversario do meu filho
#       festa aniversario do meu filho
#       festa 1 ano do meu filho
#       lembrancinha festa do meu filho
#       festa de aniversario do meu bebe
#
# - Cluster 46:
#       festa de debutante da minha filha
#       lembrancinha festa da minha filha
#       festa de 1 ano da minha filha
#       festa de 2 anos da minha filha
#       lembranca da festa da minha filha
#       lembrancinha da festa da minha filha
#       festa da minha sobrinha
#       festa da minha filha
#       festa do pijama da minha filha
#       para festa de aniversario da minha filha
#
# - Cluster 47:
#       lembrancinha de festa infantil
#       lembrancinha de formatura
#       lembrancinha para padrinhos de casamento
#       lembrancinha de pascoa
#       lembrancinha de festa
#       lembrancinha de casamento
#       lembrancinha de niver
#       lembrancinha de festa de aniversario
#       lembrancinha para festa de aniversario
#       lembrancinha festa de aniversario
#
# - Cluster 48:
#       meu uso
#       para o meu uso
#       compra para uso pessoal
#       uso
#       para uso pessoal
#       para uso meu
#       uso pessoal e presente
#       uso meu
#       para uso
#       pra uso pessoal
#
# - Cluster 49:
#       presente de aniversario de casamento
#       festa de aniversario de meu filho
#       para festa de aniversario
#       meu presente de aniversario
#       festa de aniversario de minha filha
#       festa de formatura
#       presente de aniversario
#       minha festa de aniversario
#       festa de noivado
#       enfeite para festa de aniversario
#
# - Cluster 50:
#       enxoval da minha filha
#       meu enxoval
#       enxoval
#       enxoval do meu principe
#       enxoval da minha bebe
#       enxoval do bebe
#       enxoval do meu bebe
#       enxoval do meu filho
#       enxoval de bebe
#       enxoval bebe

# %% [markdown]
# Qual é o resultado dos clusters gerados? Podemos avançar um pouco e verificar se existe alguma relação de hierarquia entre os motivos de compra.

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# TODO
Y = linkage(kmeans.cluster_centers_, method='ward', metric='euclidean')

# %%
# Obtém aleatoriamente um dos motivos para representar o cluster
titles = df.groupby('labels').apply(lambda x: np.random.choice(list(x['reason'])))

# %%
# plota o dendrograma
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=titles.values,
           leaf_rotation=90,
           leaf_font_size=14,
)
plt.show()

# %% [markdown]
# Qual foi o resultado? O que você faria para melhorar o resultado obtido?

# %% [markdown]
# ---
# # Case Elo7 - Subcategorias Automáticas
#
# Vamos para mais um case real do Elo7!
#
# Esse case é um dos trabalhos mais recentes do time de Data Science do Elo7. De fato, é um trabalho ainda em aberto e qualquer sugestão de melhorias é bem vinda! =)
#
# - O problema:
# O Elo7 possui uma árvore de categorias dividida em N1 e N2. O primeiro nível (N1) contém as categorias "alto nível" do site. São as categorias mais genéricas do marketplace- ou, pelo menos, é assim gostaríamos que fosse. As categorias N2, ou subcategorias, são as possíveis extensões dos nós das categorias N1. Podemos perceber que a árvore é extremamente limitada e isso é um problema grave não só para os compradores, que não conseguem navegar nas nossas categorias, mas também para os vendedores, que não conseguem categorizar bem seus produtos. A solução para esse problema seria uma árvore de categorias com maior "granularidade", ou seja, que consiga expandir além dos 2 níveis e ter mais subcategorias.
#
# - O que o time de Data Science tem a ver com essa história?
#
# Bom, gerar uma nova árvore de categoria pode ser uma tarefa bastante monótona e cansativa. Provavelmente deve haver algum jeito de encontrar bons agrupamentos de produtos que pudessem servir como uma nova subcategoria. Talvez algum método de clustering que utilize como features o conteúdo dos produtos pode gerar algum resultado interessante.
#
# - O experimento:
#
# O dataset a seguir possui um subconjunto de produtos que foram categorizados na categoria N1 "Casamento". Escolhemos esse conjunto de dados para iniciar nossos trabalhos, porque assim temos mais controle sobre nossos resultados. E, também, porque é uma das categorias mais importantes do marketplace.
#
# Para essa tarefa, vamos utilizar apenas o título e uma parte da descrição do produto (aprox. 140 caracteres) como features de entrada.
#
# Vamos analisar os dados!

# %%
df_cat = pd.read_csv(os.path.join(DATASET_FOLDER, 'subcategory_elo7_dataset.csv'), sep=';')

df_cat.head(10)
# Out:
#                                     title  \
# 0                    terco love ii niquel
# 1                     porta joias rustico
# 2                convite casamento lisboa
# 3                     daminhas 82 00 cada
# 4                            aromatizador
# 5  chinelo casamento personalizado noivos
# 6    monograma brasao casamento modelo 91
# 7               caixa lembrancinhas papel
# 8                body noiva personalizada
# 9        quadro casamento mario geek nerd
#
#                                    short_description  \
# 0  vc quiser simular clique produto informe cep e...
# 1  porta joias mdf presentear madrinhas lembranca...
# 2  compra minima 50 unidades convite casamento 15...
# 3                           tecido cristal voal fino
# 4  aromatizador ambientes varetas frasco vidro cu...
# 5  personalizamos qualquer tema foto precos difer...
# 6  monograma brasao casamento iniciais descricao ...
# 7  caixa cartonagem revestida papel detalhe fita ...
# 8  body personalizado madrinhas usarem despedida ...
# 9  ideal presente peca decoracao quadro eterniza ...
#
#                                         url
# 0  https://www.elo7.com.br/jfndgm/dp/36CBDF
# 1  https://www.elo7.com.br/jfndgm/dp/65FE78
# 2  https://www.elo7.com.br/jfndgm/dp/2557F0
# 3  https://www.elo7.com.br/jfndgm/dp/4D60B6
# 4  https://www.elo7.com.br/jfndgm/dp/5FECD3
# 5  https://www.elo7.com.br/jfndgm/dp/6B06A4
# 6  https://www.elo7.com.br/jfndgm/dp/B04210
# 7  https://www.elo7.com.br/jfndgm/dp/28DF6F
# 8  https://www.elo7.com.br/jfndgm/dp/AAE311
# 9  https://www.elo7.com.br/jfndgm/dp/8939E7

# %% [markdown]
# Vamos criar uma coluna com as features que vamos incluir no nosso modelo de aprendizagem.
# Esse vetor de features será o título + descrição do produto. Para compensar a quantidade de palavras do título em relação a descrição, vamos repetir o título duas vezes.

# %%
df_cat['title_desc'] = (df_cat['title'] + ' ')*2 + df_cat['short_description']

df_cat.head(10)
# Out:
#                                     title  \
# 0                    terco love ii niquel
# 1                     porta joias rustico
# 2                convite casamento lisboa
# 3                     daminhas 82 00 cada
# 4                            aromatizador
# 5  chinelo casamento personalizado noivos
# 6    monograma brasao casamento modelo 91
# 7               caixa lembrancinhas papel
# 8                body noiva personalizada
# 9        quadro casamento mario geek nerd
#
#                                    short_description  \
# 0  vc quiser simular clique produto informe cep e...
# 1  porta joias mdf presentear madrinhas lembranca...
# 2  compra minima 50 unidades convite casamento 15...
# 3                           tecido cristal voal fino
# 4  aromatizador ambientes varetas frasco vidro cu...
# 5  personalizamos qualquer tema foto precos difer...
# 6  monograma brasao casamento iniciais descricao ...
# 7  caixa cartonagem revestida papel detalhe fita ...
# 8  body personalizado madrinhas usarem despedida ...
# 9  ideal presente peca decoracao quadro eterniza ...
#
#                                         url  \
# 0  https://www.elo7.com.br/jfndgm/dp/36CBDF
# 1  https://www.elo7.com.br/jfndgm/dp/65FE78
# 2  https://www.elo7.com.br/jfndgm/dp/2557F0
# 3  https://www.elo7.com.br/jfndgm/dp/4D60B6
# 4  https://www.elo7.com.br/jfndgm/dp/5FECD3
# 5  https://www.elo7.com.br/jfndgm/dp/6B06A4
# 6  https://www.elo7.com.br/jfndgm/dp/B04210
# 7  https://www.elo7.com.br/jfndgm/dp/28DF6F
# 8  https://www.elo7.com.br/jfndgm/dp/AAE311
# 9  https://www.elo7.com.br/jfndgm/dp/8939E7
#
#                                           title_desc
# 0  terco love ii niquel terco love ii niquel vc q...
# 1  porta joias rustico porta joias rustico porta ...
# 2  convite casamento lisboa convite casamento lis...
# 3  daminhas 82 00 cada daminhas 82 00 cada tecido...
# 4  aromatizador aromatizador aromatizador ambient...
# 5  chinelo casamento personalizado noivos chinelo...
# 6  monograma brasao casamento modelo 91 monograma...
# 7  caixa lembrancinhas papel caixa lembrancinhas ...
# 8  body noiva personalizada body noiva personaliz...
# 9  quadro casamento mario geek nerd quadro casame...

# %% [markdown]
# A partir de agora é com você! Tente encontrar as subcategorias dos produtos da categoria "casamento". Lembre-se de que não queremos apenas aumentar o número de subcategorias do segundo nível (N2), mas também aumentar a profundidade da nossa árvore de categorias (N3, N4 ...).

# %%
# TODO

# %% [markdown]
# Para criar nossa matriz de features, nós vamos utilizar o Tf-Idf.

# %%
tfidf = TfidfVectorizer(max_df=0.9, max_features=10000, sublinear_tf=True, use_idf=True)

# %%
X = tfidf.fit_transform(df_cat['title_desc'].values)

# %% [markdown]
# Novamente, precisamos definir o número de clusters. Podemos utilizar o método do gráfico de inércias.
#
# (Obs: O cálculo pode levar muito tempo para ser executado. Assuma que o valor escolhido é 40)

# %%
# Range de valores de clusters que vamos testar
k = range(10,100,10)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=40)

# %%
labels = kmeans.fit_predict(X)

# %%
df = pd.DataFrame({'title': df_cat['title'], 'labels': labels})

# %%
df.groupby('labels').size()
# Out:
# labels
# 0      7943
# 1      1805
# 2      1661
# 3       614
# 4      5251
# 5      1706
# 6      1738
# 7      1763
# 8      1882
# 9      1300
# 10     1076
# 11     1715
# 12     1073
# 13     1080
# 14     2778
# 15     1345
# 16      676
# 17     3560
# 18     3626
# 19     1087
# 20     3134
# 21      523
# 22     1871
# 23     2097
# 24      439
# 25      880
# 26     2176
# 27     1957
# 28     1324
# 29      678
# 30     4097
# 31      413
# 32     1099
# 33     1564
# 34      775
# 35      221
# 36      541
# 37    28387
# 38     2906
# 39     1239
# dtype: int64

# %%
for idx in range(len(df['labels'].unique())):
    idx_labels = df[df['labels']==idx]['title'].unique()
    print('- Cluster {}:'.format(idx + 1))
    for i in np.random.choice(idx_labels, min(len(idx_labels), 10), replace=False):
        print(' '*5, i)
    print()
# Out:
# - Cluster 1:
#       alice pais maravilhas convite
#       convite casamento chalkbord quadro negro
#       convites casamento renda
#       convite sanfona padrinhos floral
#       convite casamento moderno 06 50 unidades
#       convite e3
#       convite laco cetim tiago gabriela
#       convite classico 9
#       convite casamento tipo carta
#       convite casamento caminho noiva
#
# - Cluster 2:
#       sabonete coracao lembrancinha
#       sparkles coracao romantico
#       lembrancinhas sachet coracao
#       almofada p alianca branco cx coracao
#       conjunto fronhas roubei coracao
#       kit 10 mini pregadores coracao rosa
#       lembrancinhas noivos
#       balao metalizado formato coracao vermelho 44 cm 10 unid
#       lembrancinha noivado coracao feltro
#       caixa lembrancinhas coracao
#
# - Cluster 3:
#       prazo rapido 5 dias convite formatura
#       convite padrinhos madrinhas
#       numerados
#       convite casamento
#       convite casamento colecao esguio
#       convites colecao royal casamento
#       convite casamento colecao royal clean
#       convite casamento personalizado
#       casamento placas
#       manual padrinhos
#
# - Cluster 4:
#       pista danca 1x1 personalizada 93
#       tapete adesivo pista danca
#       tapete pista danca 15 anos 1 5x1 5 md08
#       pista danca personal 5x5 metros
#       pista danca 2x2 personalizada 33
#       pista danca 1x1 personalizada 79
#       pista danca 2x2 personalizada 85
#       pista danca 2x2 personalizada 81
#       pista danca 1x1 personalizada 92
#       adesivo pista danca 4x4 personalizada 17
#
# - Cluster 5:
#       caixa 20 lembrancinhas alcool gel
#       caixa padrinhos batizado mod 01
#       caixa forracao tecido lembranca
#       caixa floral
#       caixa decorar ambiente
#       caixa mdf personalizado padrinhos
#       caixa lembranca padrinhos bordada
#       caixa biombo 3 andares 3 1
#       casal caixa acetato
#       caixa convite padrinhos n 284 completo
#
# - Cluster 6:
#       caneca porcelana mini mug
#       caneca porcelana bigode grosso
#       caneca acrilica angry bird
#       caneca acrilico personalizada 500 ml
#       caneca cha bar tubaina
#       canecas personalizadas casamento
#       caneca porcelana personalizadas casamento
#       caneca casamento rosas 6729
#       caneca padrinho bigode 20 modelos
#       caneca cafe noivinhos mod 013
#
# - Cluster 7:
#       noivinhos fofinho
#       noivinhos motoca
#       noivinhos juliana jorge
#       topo bolo noivinhos estilo doll
#       topo bolo casamento noivinhos biscuit
#       noivinhos fofuxos
#       topo bolo biscuit noivinhos fofinhos videogame cachorros
#       topo bolo noivos motocross
#       topo bolo noivinhos casamento luzes coloridas
#       bolo falso noivinhos
#
# - Cluster 8:
#       gravata borboleta preta adulto ba36
#       gravata preta trabalhada n63c
#       caixa passar hora gravata
#       forminha marsala tecido tela
#       adesivo hora gravata to duro
#       forminha docinhos
#       gravata prata trabalhada abst
#       cofre personalizado g dinheiro gravata
#       gravata preta poa t95
#       forminha doces rendada
#
# - Cluster 9:
#       fio cabelo noiva perolas 1 20
#       brinco cristais prata
#       tiara retorcida
#       tiara heliene
#       brincos zirconia br001
#       headband faixa crianca noiv tiara perola
#       brinco puro glamour
#       brinco cristal premium
#       tiara dupla acessorio cabelo noivas strass perolas lux
#       coroa tiara cabelo noiva strass
#
# - Cluster 10:
#       chinelo casamento coracoes amarelos
#       chinelos casamentos chinelos
#       chinelo casamento personalizado madrinha
#       chinelo personalizado madrinhas
#       chinelo personalizado filtro sonhos 02
#       chinelo casamento 22 estampa
#       saquinho chinelos personalizados
#       chinelo personalizado casamento 71
#       chinelo branca neve
#       saquinhos chinelo fita cetim
#
# - Cluster 11:
#       convite rustico chic k001
#       convite casamento rustico azul
#       convite rustico cv 186 linhao
#       convite casamento rustico mod 1150
#       convite casamento rustico cetim
#       convite coracao rustico barato simples
#       convite casamento rustico i
#       convite bodas rustico
#       convite rendado rustico
#       a4 convite rustico flores envelope dourado
#
# - Cluster 12:
#       bouquet noiva cascata porta aliancas
#       boneca nanda porta aliancas
#       porta aliancas flor
#       porta aliancas dalia
#       porta aliancas bola perolas cor perola
#       porta aliancas bau perolas
#       porta aliancas c flores rustico vintage
#       cestinha porta aliancas plumas
#       porta aliancas coracao champanhe
#       mini buque porta aliancas
#
# - Cluster 13:
#       caixinha doce bem casado flor
#       forminhas bem casados
#       caixinha craft bem casados docinhos
#       caixinha bem casado m c tag kraft
#       tecido bem casado c 50 unidades
#       botao perolas bem casados
#       caixa rendada casamento
#       400 flores camelia p bem casado
#       caixinha bem casado renda
#       caixa 1 bem casado
#
# - Cluster 14:
#       lagrimas alegria classica
#       lenco lagrimas alegria 14x14
#       l150 lagrimas alegria tecido
#       lagrimas alegria floral vintage
#       lagrimas felicidade
#       lagrimas alegria clear 100 unidades
#       lagrimas alegria noivinhos
#       lagrimas alegria papel perolado prata
#       lagrimas alegria personalizadas
#       200 lagrimas alegria passaros noivos
#
# - Cluster 15:
#       pronta entrega buque pimentas
#       buque piriguetes preco cada boneca
#       kit buque noiva mini buque lapela
#       buque noiva branco c cabo rose
#       buque feltro coracoes amarelo
#       buque flower lady
#       buque noiva cupidos feltro 8 pecas
#       buque azul royal buque jogar
#       buque noiva pink roxo branco
#       buque sapos sapinha noiva
#
# - Cluster 16:
#       kit bonecos pajem porta alinca
#       boneca floral lilas
#       boneca 30 cm
#       boneca noiva barbie gold
#       boneca daminha provencal 02
#       convite arvore amarelo
#       boneca madeira frida
#       bonecas festa
#       isabela
#       almofada formato daminha pajem
#
# - Cluster 17:
#       prazo 5 dias uteis convite 50 anos
#       convite pajem daminha
#       convite casamento colecao esguio
#       convite pais padrinhos
#       convite padrinhos
#       kit soneca convite pajens daminhas
#       convite aniversario
#       porta guardanapo
#       nomes convidados
#       porta guardanapos
#
# - Cluster 18:
#       noiva sapato vermelho
#       casal caveira mexicana topo bolo
#       topo bolo modelo realista
#       topo bolo formatura publicidade
#       topo bolo biscuit game
#       topo bolo luciana
#       topo bolo amo
#       topo bolo noivos
#       topo bolo mdf decoracao casamento m9
#       bolo cha lingerie
#
# - Cluster 19:
#       noivinhos biscuit personalizados
#       noivinhos gesso dourado
#       noivinhos cachorrinhos
#       noivinhos personalizados rugby
#       noiva puxando noivo modelo humanizado
#       noivinha amarrando noivo flamenguista
#       noivo cozinheiro
#       noivinhos dancando modelo humanizado
#       noivos piloto greve modelo humanizado
#       noivinhos madeira time tatto
#
# - Cluster 20:
#       toalha padrinhos madrinhas personalizada
#       toalha lavabo bordada madrinha
#       jogo toalhas noivinhos
#       pronta entrega apenas r 15 00 cada
#       kit 10 toalha mesa oxford casamento
#       jogo toalhas bodas prata ouro 1
#       caixa pajem toalha bordada sabonete
#       toalha rosto macrame
#       jogo toalhas bordadas
#       toalha lembrancinha c coracao azul
#
# - Cluster 21:
#       arte plaquinhas rosa cha verde menta
#       convite padrinhos casamento arte
#       arte digital convite
#       convite digital cha panela whatsapp
#       monograma brasao casamento arte digital mod 7
#       arte menu open bar
#       arte digital convite casamento dig 01
#       convite digital casamento passaros
#       arte digital convite casamento 0005
#       arte digital tag nome convidados
#
# - Cluster 22:
#       santo antonio boneco tecido
#       santo antonio almofada
#       lembrancinha santo antonio sabonete
#       quadrinho santo antonio
#       pronta entrega buque santo antonio
#       buque santo antonio grande 5
#       kit noiva
#       porta canetas santo antonio
#       sache almofadinhas perfumadas santo antonio
#       plaquinha mdf santo antonio ajuda
#
# - Cluster 23:
#       colher pau personalizada
#       tag cadeira noivos
#       brindes ecologios lembrancinhas
#       aromatizador 60ml sacola
#       tag mini lixas cha lingerie
#       lembrancinha cha panela
#       tag lousa
#       tag redonda lembrancinhas paris
#       lembranca bau amendoas italianas
#       caixinhas personalizadas
#
# - Cluster 24:
#       novidade mini porta joia oval
#       porta docinhos bombom
#       porta bombom carruagem
#       almofada porta alianca rosa
#       porta latinhas personalizado casamento
#       porta alianca perola
#       mini porta joia pedrinhas strass
#       porta vinho g
#       porta alianca daminha
#       porta coque p damas noivas debutante
#
# - Cluster 25:
#       sacola preta long drink taca
#       copo long drink noivado 2
#       copo long drink metalizado 15 anos evento
#       kit daminha
#       copo long drink 350 ml perola
#       copo long personalizados
#       copo borda kit padrinhos c 20 copos
#       copo acrilico long drink plastico person
#       copos acrilico long drink twister
#       copo long drink start new game
#
# - Cluster 26:
#       chinelo casamento personalizado 54
#       chinelo casamento senhor bonfim
#       chinelo casamento aneis passaros
#       chinelo casamento coracao noivo noiva
#       chinelo casamento coracoes azul
#       sandalias casamento arabescos
#       chinelo casamento personalizado 0153
#       chinelo casamento marrom personalizado
#       chinelo casamento personalizado 0007
#       sandalias casamento noivo
#
# - Cluster 27:
#       placa seta indicativa rustica 2 pl
#       placa hoje duas familias tornam
#       placa aqui comeca historia
#       placa arabesco 29x19 mdf
#       placa papai noel
#       placa cadeira noivos
#       kit 02 placa personalizada 01 caixa
#       placa direcional heart
#       placa noivo fuga arabescos
#       placa carro bodas porcelana
#
# - Cluster 28:
#       cabide mdf inicias noivos c aplique
#       cabide casamento personalizado
#       robe cetim personalizado
#       robe cetim bordado coroa 15x11 cm
#       cabide mae noiva perolas
#       cabide personalizado branco cristais salpicados
#       robe cetim diurado marsala
#       cabide anfitria
#       cabide mod 14 brasao
#       robe madrinhas
#
# - Cluster 29:
#       terco noiva perolas brancas
#       terco fernanda grande vermelho siam
#       terco noiva personalizado
#       terco devocao personalizado
#       terco coroacao familia
#       terco porta senhora aparecida
#       terco rainha gracas cintia folheado
#       terco noiva perola niquel
#       lembranca sache perfumado terco
#       terco cristal banhada prata cod 55
#
# - Cluster 30:
#       arranjo torcidinho encanto
#       mini arranjo origami sakura 2
#       arranjo cabelo rosas cetim
#       arranjo medio cabelo daminha
#       kit bolo v arranjo mesa convidados
#       arranjo flor laco branco
#       arranjo noiva rose
#       coroa flores aurora
#       arranjo floral cabelo classic bride
#       adele arranjo noiva
#
# - Cluster 31:
#       kit ressaca box brinde
#       kit champagne rose rosas
#       kit macarronada uvas ceramicas
#       avental garrafa jacquard kit 10pcs
#       kit noiva 6 pecas
#       camisa love dia namorados kit 2 pcs
#       kit toalete completo 57 itens
#       kit 50 balas 50 chicletes casamentos
#       kit madrinha sabonete hidratante
#       kit aromatizador sais banho natal
#
# - Cluster 32:
#       placa la vem noiva
#       plaquinha la vem noiva 20x40cm
#       placa coracao la vem noivo
#       coroa flores la vem noiva
#       placa casamento madeira la vem noiva
#       placa la vem noiva frente enfim ca
#       placa la vem noiva iii
#       placa casamento frase la vem noiva outras mdf branco
#       placa rustica la vem noiva
#       placa la vem noiva tiffany
#
# - Cluster 33:
#       convite azul tiffany debutante 15 anos
#       convite 15 anos floral bico
#       convite olavo 80 anos
#       cone tecido convite
#       caricatura bodas 15 anos cristal
#       caixa convite box luxo padrinho casamento
#       convite 15 anos convite casamento 240g 00
#       convite casamento 15 anos petalas
#       brasao 008 casamento 15 anos
#       almofadas casamento batizado 15 anos
#
# - Cluster 34:
#       almofadinha renascenca redondinha
#       kit flor gigantes 5 unidades ariana 50cm
#       flor 6cm renda renascenca
#       flor noiva penas brancas
#       forminha buquet flor pessegueiro
#       vestido infantil bella flor
#       flor cetim 5cm 008
#       flor camelia gigante 25 cm
#       lembrancinha noivado
#       flor lapela amarela
#
# - Cluster 35:
#       save the date digital celular
#       convite casamento barato 9 digital top profissional
#       placa save the date rustica madeira
#       save the date mdf 9x5 5cm ima modelo 1 premium
#       placas p save the date rustico mod iii
#       save the date noivinhos facebook
#       monoculo ver sempre amor
#       convites casamento 11 digital personalize sonho
#       save the data
#       manual padrinhos ii save the date ima
#
# - Cluster 36:
#       chinelo personalizado casamento cod 0231
#       chinelo personalizado casamento cod 0147
#       chinelo personalizado casamento cod 1196
#       chinelo personalizado casamento cod 1153
#       chinelo personalizado casamento cod 1138
#       chinelo personalizado casamento cod 0235
#       chinelo personalizado casamento cod 0175
#       chinelo personalizado casamento cod 0143
#       chinelo personalizado casamento cod 0174
#       chinelo personalizado casamento cod 0245
#
# - Cluster 37:
#       alianca moeda reta 2 frisos 7mm
#       par abotoaduras ab31
#       alianca ouro polida tradicional
#       alianca moeda antiga reta 8mm
#       par aliancas 8mm anatomicas 15 pedras
#       alianca casamento moeda antiga meio polida meio fosca 8 mm
#       alianca folheada ouro prata
#       par aliancas moeda antiga casamento
#       aliancas casamento ouro 18k 750
#       par aliancas modelo bo 07
#
# - Cluster 38:
#       pocket lenco nature corujinhas
#       motos 003 lambreta
#       display mesa minions
#       urna lua mel
#       ima personalizado galinha pintadinha
#       petalas rosa amarela 150 unds
#       cofrinhos personalizados casamento
#       plaquinha personalizada sabores
#       pombinhos tronco
#       havaianas top noivo
#
# - Cluster 39:
#       porta guardanapo perola 12mm dourado
#       guardanapo oxford 30x30
#       porta guardanapo gota azul
#       porta guardanapo sofisticado
#       ref 2780 porta guardanapo chanel
#       porta guardanapo minie
#       porta guardanapo bailarina argola strass
#       guardanapo fazendinha
#       porta guardanapo rosa vermelha
#       porta guardanapo glamour ouro
#
# - Cluster 40:
#       quadro assinatura convidados
#       quadro 80 coracoes vermelho
#       quadro assinaturas areia ii
#       arvore assinaturas passarinhos 40x35
#       quadro assinaturas casamento arte
#       arvore digitais 60x80cm
#       quadro digitais personalizado
#       quadro mickey minnie casal
#       kit 80 assinaturas rosa
#       quadro 80 assinaturas personalizado marsala completo

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

Y = linkage(kmeans.cluster_centers_, method='ward', metric='euclidean')

# %%
titles = df.groupby('labels').apply(lambda x: np.random.choice(list(x['title'])))

# %%
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=titles.values,
           leaf_rotation=90,
           leaf_font_size=14,
)
plt.show()
